# %%
from vhagilab.openai_client import *

# %%
#set_config("openai_client_config")

# %%
threads_id = [row.strip() for row in open("thread_to_purge.txt") if row.strip()]

# %%
delete_threads(threads_id)

# %%
exit
